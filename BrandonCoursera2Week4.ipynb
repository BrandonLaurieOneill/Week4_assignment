# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Brandon O'Neill**
# Agricultural Engineer

# %% [markdown]
# *Because I have a master's degree in my topic of interest and job experience in it, I am interested in data science. The next step for me would be to enhance my data expertise within the area in order to broaden my skill set and maintain my passion in agriculture.*

# %% [markdown]
# ### The next cell will calculate a simple equation of my total years of experience which will be years of study added to my work experience.

# %%
years_studied = 7
years_worked = 3
total_experience = years_studied + years_worked
print(f"I have {total_experience} years of experience in agriculture")
# Out:
# I have 10 years of experience in agriculture

# %% [markdown]
# #### I will tell you a little bit about myself using the table below.
#
# **My university**
# ![JUNIA_logo.png](attachment:23b65417-ece3-42ab-98c0-849c5128d089.png)
#
# *More about me*
#
# | Origin | Residence | Occupation |
# | ------ | ------ | ------|
# | South African | France | Agricultural Engineer |
#
# **Some of the things I like**
# - hiking
# - swimming
# - travelling
